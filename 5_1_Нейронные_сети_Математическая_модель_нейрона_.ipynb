# %% [markdown]
# **Навигация по уроку**
#
# 1. Нейронные сети. Математическая модель нейрона.
# 2. [Нейронные сети. Функции активации.](https://colab.research.google.com/drive/1mhEEhb3mdE5mKFIvOiC5tHvkPiWD8DBj)
# 3. [Домашняя работа](https://colab.research.google.com/drive/19VE4qs0K7XjAfkcVbwmLpGR5yKKhXyYV)

# %% [markdown]
# **В данном уроке мы изучим:**
#
# 1.   Базовые понятия ИИ
# 2.   Где используются нейронные сети?
# 3.   Принцип работы нейрона
# 4.   Математическую модель нейрона
# 5.   Функции активации

# %% [markdown]
# Full explaining https://monica.im/home/chat/Monica/monica?convId=conv%3Ad1fe6161-8e50-4557-b17c-88a88f897670

# %% [markdown]
# ## Базовые понятия ИИ

# %% [markdown]
# **Искусственный интеллект (ИИ — artificial intelligence, Al)** — это область информатики, в рамках которой разрабатываются компьютерные программы для решения
# задач, требующих **имитации мыслительной деятельности человека**. Такие программы могут делать обобщения и выводы, выявлять взаимосвязи и обучаться с учетом
# накопленного опыта.
#
# **Системы искусственного интеллекта ни в коем случае не
# заменяют человека — они расширяют и дополняют его возможности.**
#
# Два ключевых понятия в системах искусственного интеллекта — это **нейронные
# сети** и **машинное обучение**.
#
# **Нейронная сеть** - это математическая модель и ее программная реализация, которая в упрощенном виде воссоздает работу биологической нейронной сети человека.
#
# **Машинное обучение** — это набор специальных алгоритмов, благодаря которым воплощается ключевое свойство нейронных сетей — способность самообучения на основе получаемых данных. Чем больший объем информации будет представлен в качестве тренировочного массива данных, тем проще обучающим алгоритмам найти закономерности и тем точнее будет выдаваемый результат.

# %% [markdown]
# Существует несколько видов искусственного интеллекта, среди которых можно
# выделить три основные категории:
# 1. **Ограниченный искусственный интеллект (artificial narrow intelligence, ANI)** - представляет собой программно-аппаратный комплекс, специализирующийся
# исключительно в одной конкретной области. Например, компьютерная программа может победить чемпиона мира по шахматам в шахматной партии, но проиграет ребенку в крестики-нолики. Она спроектирована под одну конкретную задачу.
#
# 2. **Общий искусственный интеллект (artificial general intelligence, AGI)** - представляет собой программно-аппаратный комплекс, чей интеллект напоминает
# человеческий, может выполнять все те же задачи, что и человек.
# Общий искусственный интеллект позволяет копировать мыслительные способности человека: получать данные, выделять из потока данных нужную информацию, сравнивать различные варианты решения задачи, быстро обучаться, использовать накопленный опыт.
#
# 3. **Искусственный суперинтеллект (artificial superintelligence, ASI)** - это интеллект, который превосходит человеческий практически во всех областях, включая научные изобретения, общие познания и социальные навыки. На текущем этапе научного развития суперинтеллект, пока недостижим.

# %%
###############################

# %% [markdown]
# ## Сферы применения искусственного интеллекта

# %% [markdown]
# Различают интеллектуальные и неинтеллектуальные задачи.
#
# *Неинтеллектуальные задачи* – это последовательность действий, выполняемых по определенному алгоритму. Фактически это задачи, которые можно представить в виде алгоритмов, решением этих задач и занимаются программисты, инженеры и ученные. Сборка автомобиля - это чисто алгоритмическая задача. Инженер-технолог может полностью расписать весь процесс на бумаге, от литья, штамповки, последовательности соединения узлов и агрегатов.
#
# Основная область применения ИИ – это интеллектуальные задачи. Это те задачи, которые не возможно решить последовательностью действий. Например, чтобы придумать новый тип двигателя автомобиля, его дизайн, новые характеристики, то тут уже нужны интеллектуальные навыки. Это те навыки, которым надо обучаться, наблюдать за примерами из природы, анализировать опыт конкурентов, если мы говорим про автомобиль. Также и ИИ обучается на тех данных, что мы ей предоставим. От качества данных (применительно к ИИ набор данных для обучения называют датасетами) зависит и конечный результат.

# %% [markdown]
# ![self-driving.png](data:image/png;base64,...)
#
#
#
# *Рис. 1. Так видит беспилотный автомобиль нейросеть StableDiffusion из первого урока*

# %% [markdown]
# Приведем реальные примеры использования ИИ:
# 1. **ИИ и интернет**. С появлением ИИ в интернете появилось большое количество сервисов, большинство из которых мы рассмотрели на первом занятии. Но список значительно шире. Крупные поисковые гиганты, такие как Google или Yandex, активно стали внедрять ИИ в свои поисковые алгоритмы. Так Google внедрил в алгоритм поиска свою языковую модель BERT, и поиск стал формироваться на основе анализа не только ключевых слов, но и целых предложений. На одном из уроков мы коснемся переобученной на русских датасетах языковой модели ruBERTa (в простонародье Руберта), ее еще называют русской версии RoBERTa. Как вы уже догадались у BERT'a большое потомство.
#
# 2. **Транспорт и логистика.** Примерно с 2000-х многие автопроизводители, с переменным успехом, занялись разработкой беспилотных автомобилей. Что вызвало настоящий бум развития беспилотных технологий, не только в автомобильной промышленности, но и в оптимизации грузоперевозок, навигации, появились "умные" дорожные системы и разметки. Началась эра использования беспилотных летательных аппаратов в доставке товаров и грузов.
#
# 3. **Искусственный интеллект в финансах.** Все больше и больше платежных систем и банков используют ИИ в анализе транзакций для выявления подозрительной активности. Такие системы с одной способны обнаружить мошеннические операции и заблокировать их, а с другой защитить от ложных срабатываний систем безопасности и отклонения транзакций, так как постоянно обучаются на новых данных.
#
# 4. **ИИ в бизнесе.** ИИ способен анализировать покупательскую активность клиентов, фиксировать их взгляды на камеры торговых центров, анализировать чеки, а после "допродавать" не купленный ранее товар через мобильные приложения, смс рассылки. В общем использовать по максимуму нашу с вами любовь к гаджетам и скидочным картам лояльности.
#
# 5. **Медицина.** Как бы это не звучало пафосно, но ИИ уже научились спасать человеческие жизни. Искусственный интеллект распознает патологии на рентгеновских снимках, маммографии, МРТ, КТ. С помощью ИИ врачи выявляют заболевания легких, болезнь Альцгеймера. На изучение результатов исследования искусственному интеллекту требуется несколько секунд, а врачу – гораздо больше, от нескольких минут до недель.
#
# > Самый известный компьютерный диагност – IBM Watson. В его память загружены миллионы медицинских документов и истории болезней. Примечательно, что IBM Watson ставит диагнозы точнее врачей. Лечащий врач, руководствуясь советами ИИ, самостоятельно примет решение о диагнозе и методах лечения, но вероятность врачебных ошибок значительно снижается.
#
# > Другой пример отечественного ИИ – Botkin.AI. Это настоящий помощник онкологам. Система проводит многосторонний анализ результатов обследований, дает подсказки и советы врачам.
#
# 6. **Военная сфера.** В 2018 году стало известно, что в армии США ведутся разработки системы, которая сможет распознавать лица людей в темноте и сквозь стены, посредством тепловизора. Главным ее назначением, как планируют создатели, должна стать задача по выявлению главарей банд в локациях, где проходят военные действия. Другое направление, которое активно развивает Китай - это рой дронов. Благодаря искусственному интеллекту и распределенным базам данных, огромные колонны беспилотников могут выполнять поставленные задачи, даже в условиях потери до 90% колонны.
#
# 7. **Системы безопасности.** ИИ используется в системах безопасности в первую очередь для распознавания лиц и идентификации личности. Дополнительно «умные» системы применяют с целью выявления опасных предметов и веществ. Кроме того, ИИ оказывает помощь и в кибербезопасности. Анализируя массивы данных об угрозах, искусственный интеллект сокращает время отклика служб безопасности и расширяет их возможности для более быстрого реагирования.
#
# 8. **Космические исследования.** В космосе, в агрессивных условиях, где не может работать человек, на себя всю работу берут космические беспилотные устройства и системы принятия решения. Одна из задач, которую решают ИИ, и мы похожие задачи рассмотрим на курсе, это задачи прямохождения роботов и посадка космического корабля.
#
# 9. **ИИ в спорте.** ИИ не только помогают спортсменам держать себя в форме, предсказывать режимы оптимальных тренировок и питания, но все чаще берут на себя задачи судейства, анализируя данные с камер.
#
# 10. **ИИ в культуре.** Генеративные нейронные сети научились писать картины, создавать музыку, писать рассказы, общаться с людьми в качестве ассистентов и консультантов.
#
# 11. **Системы принятия решений.** Один из самых обширных блоков использования нейронных сетей. Их используют в политике, судебной системе, в промышленности и производстве, сельском хозяйстве, в научной деятельности, в закупке сырья и материалов, выступать в качестве специалистов и предлагать свои решения задач (так называемые экспертные системы). Так, например, Барака Обама, на вторых президентских выборах, нанял команду профессионалов, которая использовала ИИ. Нейросети отвечали за расчет лучших дней и выбор локаций для проведения агитационных мероприятий, что дало перевес в 10-12%.

# %% [markdown]
# Как вы видите, все эти примеры относятся к области интеллектуальных задач и алгоритмическим подходом их не решить!!!

# %%
###############################

# %% [markdown]
# ## Как же это все работает?

# %% [markdown]
# **Теперь** разберемся как это все работает. Для этого надо разобраться с таким понятием, как искусственная нейронная сеть и искусственный нейрон.
#
# Раз есть искусственный, значит есть и естественный. Все верно. В школьном курсе рассматриваются биологические нейронные сети. А находятся они в голове, а точнее в мозге. Мозг есть не только у человека, но и у многих других животных. Наш мозг представляет собой сложнейшую биологическую нейронную сеть, которая принимает информацию от органов чувств (глаза, уши, нос), каким-то образом ее обрабатывает (узнает лица, распознает речь, ощущает запахи и т. д.). На основе полученных данных она дает команды различным органам (выработать слюну при виде "пюрешочки с котлеткой", пойти к доске по просьбе учителя, спрятаться когда страшно, дрожать когда холодно). Все эти действия выполняет наш мозг, опираясь на биологическую нейронную сеть, состоящую из совокупности нейронов. В головном мозге человека общая нейронная сеть содержит примерно 86 млрд нейронов, соединенных друг с другом миллиардами связей.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# *Рис. 2. Нейрон и схема передачи импульсов между нейронами*

# %% [markdown]
# Тело нейрона
#
# Синапсы  المشابك العصبيه
#
# Дендриты  التشعبات
#
# Аксон  محور عصبي
#
# Движение импульса

# %% [markdown]
# Биологический нейрон — это нервная клетка, состоящая из тела, дендритов и аксона. От тела отходит множество коротких и толстых отростков, называемых дендритами. Это входные отростки — они принимают импульсы с тех нейронов, которые находятся в сети раньше, чем этот нейрон. От тела отходит также один очень длинный и тонкий отросток, называемый аксоном. Это выходной отросток — по
# нему нейрон передает электрохимический импульс следующим нейронам в сети.
# Окончание аксона имеет разветвления, через которые выходной сигнал может быть
# передан нескольким следующим нейронам. Таким образом, через множество дендритов нейрон получает входные сигналы, в теле нейрона они обрабатываются, а через единственный аксон выходной импульс от нейрона передается дальше. Реальный биологический нейрон является достаточно сложной системой. Во многом это объясняется тем, что нейрон, помимо обработки сигнала (основное его назначение), вынужден еще выполнять множество других функций, поддерживающих
# его жизнь. Более того, сам механизм передачи сигнала от нейрона к нейрону тоже
# очень сложный с биологической и химической точек зрения.

# %% [markdown]
# ![Снимок экрана 2023-10-25 214252.png](data:image/png;base64,...)
#
# *Рис. 3. Схема искусственного нейрона*

# %% [markdown]
# Выше представлена примитивная модель нейронна в виде «черного ящика», который принимает на входе данные ($x_1$, $x_2$), выполняет с ними некоторые операции, а затем выводит результат — $y$.

# %% [markdown]
# #### Как нейроны взаимодействуют между собой в нейронной сети?

# %% [markdown]
# Дело в том, что аксон каждого нейрона на своем конце имеет большое количество так называемых синапсов. Синапс— это место соединения выходного аксона одного нейрона с входными дендритами другого нейрона.
#
# Через синапс передается нервный импульс. А сам нервный импульс формируется в теле нейрона, которое фактически выступает сумматором, принимающим все входные импульсы, взвешивающим их, передающим их в некоторую активирующую функцию и принимающим решение, запускать импульс дальше по своему аксону или нет. Решение принимается очень просто — если суммарные входные импульсы превышают некий заданный порог, то выходной импульс запускается.
#
# Для реализации искусственного нейрона нужно построить его упрощенную математическую модель, в которой были бы реализованы его базовые функции без
# учета функций жизнеобеспечения.

# %%
###############################

# %% [markdown]
# ## Математическая модель нейрона

# %% [markdown]
# Первую математическую модель искусственного нейрона и основанную на нем модель нейронной сети предложили в 1943 г. американские ученые — нейрофизиолог Уоррен Мак-Каллок и математик Уолтер Питтс (см. рис. 4.).

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Рис. 4. Математическая модель искусственного нейрона

# %% [markdown]
# Эта модель очень простая. На вход математического нейрона поступает некоторое количество входных параметров: $x_1$, $x_2$, ..., $x_n$, как бы от дендритов, и каждый входной параметр имеет свой вес: $w_1$, $w_2$, ..., $w_n$.
# В теле искусственного нейрона имеется *сумматор*, где каждый входной сигнал умножается на некоторый действительный весовой коэффициент, в результате чего формируется итоговая сумма. Полученное значение передается в *функцию активации*. Перед выходом из тела нейрона осуществляется проверка значения этой функции — если оно выше некоторого порога, то на выходе из тела нейрона формируется значение, равное единице. В этом случае нейрон *активируется*, и в аксон передается соответствующий сигнал. Если же итоговое значение в функции активации ниже порога, то на выход из тела нейрона подается значение, равное нулю, и нейрон считается *неактивированным*.
#
# Таким образом в сумматоре мы имеем функцию:
#
# $S = x_1w_1+x_2w_2+...+x_nw_n$
#
# Роль сумматора здесь очевидна: он преобразует все входные сигналы (которых может быть много) в одно число — взвешенную сумму, характеризующую поступивший на нейрон сигнал в целом.
#
# Часто в взвешенную сумму добавляют смещение. Это делается для того, чтобы убрать линейные преобразования в функции активации и вынести их в сумматор. Тогда мы получаем, что сумматор производит только линейные преобразования, а функция активаци, как правило нелинейные (исключение, линейная функция активации).
#
# Тогда в общем виде в сумматоре мы имеем функцию:
#
# $S = x_1w_1+x_2w_2+...+x_nw_n + b$, где $b$ - смещение

# %% [markdown]
# Реализуем сумматор в виде следующего программного кода:

# %% [markdown]
# Вектор المتجه https://monica.im/home/chat/Monica/monica?convId=conv%3A560c7584-6d9e-40bc-88b0-d68901b5a4b2
#
# https://monica.im/home/chat/Monica/monica?convId=conv%3A90c13a18-a870-4eda-8854-c4fec98292bc

# %%
# https://monica.im/home/chat/Monica/monica?convId=conv%3A543247c3-5983-4b1e-a6dc-eca5bdbf0ed7
# https://monica.im/home/chat/Monica/monica?convId=conv%3A52292cda-635a-4b84-a15b-c66c4ba9a41c

import numpy as np


class Neuron:
    def __init__ (self, w):
        self.w = w

    def у(self, x) :
        s = np.dot(self.w, x) # Сумматор вычисляется как матричное умножение вектора весов на входной вектор
        # np.dot() ===> https://monica.im/home/chat/Monica/monica?convId=conv%3A38db75ea-5f68-4d1d-aa9c-14aaad7cb0dd
        return s


### Суммируем входы
# Задаем входной вектор
Xi = np.array([2, 3]) # Преобразуем входной список в входной вектор
# Задаем вектор весов
Wi = np.array([1, 1]) # Получаем вектор весов

n = Neuron(Wi) # Создание объекта из класса Neuron
print('S = ', n.у(Xi))
# Out:
# S =  5

# %%
import numpy as np

class Neuron:

    # Атрибут
    def __init__ (self, w):
        self.w = w

    # Метод
    def y(self, x):
        s = np.dot(self.w, x)     # s == np.dot(self.w, x) == np.dot(n, y(Xi))
        return s

Xi = np.array([2, 3])
Wi = np.array([1, 1])

n = Neuron(Wi)                    # n == Neuron(Wi) == self.w = w = Wi
print('S = ', n.y(Xi))
# Out:
# S =  5

# %% [markdown]
# В примере выше мы создали класс Neuron, в теле которого подсчитывается сумма произведений входного параметра на его вес. Для работы с массивами данных мы используем библиотеку numpy, с которой мы детально познакомимся на следующем уроке. Сейчас же нам важно знать о этой библиотеке следующее:
# 1. Библиотека работает с массивами. Метод *np.array* - преобразует список в массив.
# 2. Одномерный массив - принято называть вектором.
# 3. Метод *np.dot* - вычисляет матричное произведение двух векторов.
# 4. Сумматор, который мы исследуем, представляет собой матричное умножение входного вектора на вектор весов.

# %% [markdown]
# Отвлечемся от теории и спросим у нейронной сети, умеющей генерировать изображения: Что такой нейронная сеть? Ответ StableDiffusion представлен на рис. 5.

# %% [markdown]
# ![Без названия (3).png](data:image/png;base64,...)
#
# Рис. 5. Так нейронная сеть StableDiffusion нарисовала "сама себя"

# %% [markdown]
# В следующей части урока мы рассмотрим функцию активации нейрона. [Иду дальше](https://colab.research.google.com/drive/1mhEEhb3mdE5mKFIvOiC5tHvkPiWD8DBj#scrollTo=gkmjcJWVJMyP).
