# %% [markdown]
# **Навигация по уроку**
#
# 1. Функции. Классы и объекты. Програмные модули
# 2. Практика кода
# 3. Домашняя работа

# %% [markdown]
# ## Упражнение 1. Случайный пароль

# %% [markdown]
# **Условие.** Напишите функцию, которая будет генерировать случайный пароль. В пароле должно быть от 7 до 10 символов, при этом каждый символ должен быть случайным образом выбран из диапазона от 33 до 126 в таблице ASCII. Ваша функция не должна принимать на вход параметры, а возвращать будет сгенерированный пароль. В основной программе вы должны просто вывести созданный случайным образом пароль. Программа должна запускаться только в том случае, если она не импортирована в виде модуля в другой файл.

# %% [markdown]
# > **Подсказка.** При решении этого упражнения вам понадобится функция
# chr. Полную информацию о ней можно найти в интернете.

# %%
import random

def generate_password():
    # Генерируем случайную длину пароля от 7 до 10
    password_length = random.randint(7, 10)
    # Создаем пароль, выбирая случайные символы из диапазона ASCII (33-126)
    password = ''.join(chr(random.randint(33, 126)) for _ in range(password_length))
    return password

# Основная программа
if __name__ == "__main__":
    print("Случайный пароль:", generate_password())
# Out:
# Случайный пароль: k}[A}m";/

# %%
# Print hiii 5 times
for _ in range(5):
    print("HIII")
# Out:
# HIII
# HIII
# HIII
# HIII
# HIII

# %% [markdown]
# **Перепишите код решения и запустите его**
#
# ![image.png](data:image/png;base64,...)

# %%
# Ваш код
# https://monica.im/home/chat/Monica/monica?convId=conv%3A5b914b9c-bdd2-490d-939c-c2e960d560a1


from random import randint

def randomPassword():
    randomLength = randint(7, 10)

    result = ""
    for i in range(randomLength):
        randomChar = chr(randint(33, 126))
        result = result + randomChar

    return result

def main():
    print('Random Password =====>>>', randomPassword())

if __name__ == "__main__":
    main()


### Another way
# import random
# def generate_password():
#     password_length = random.randint(7, 10)
#     password = ''.join(chr(random.randint(33, 126)) for _ in range(password_length))
#     return password
# if __name__ == "__main__":
#     print('RANDOM PASSWORD =====>>>', generate_password())
# Out:
# RANDOM PASSWORD =====>>> GI$)q)"<

# %% [markdown]
# ## Упражнение 2. Проверка пароля на надежность

# %% [markdown]
# **Условие.** В данном упражнении вам необходимо написать функцию, проверяющую
# введенный пароль на надежность. Определим как надежный пароль, состоящий минимум из восьми символов и включающий хотя бы по одной букве в верхнем и нижнем регистрах и как минимум одну цифру. Функция должна возвращать True, если переданный в качестве параметра пароль отвечает требованиям надежности. В  противном случае возвращаемым значением должно быть False. В основной программе необходимо запросить у  пользователя пароль и  оповестить его о том, является ли он достаточно надежным. Программа должна запускаться только в том случае,
# если она не импортирована в виде модуля в другой файл.

# %% [markdown]
# **Перепишите код решения и запустите его**
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# Ваш код

def checkPassword(password):
    has_upper = False
    has_lower = False
    has_num = False

    for ch in password:
        if ch >= "A" and ch <= "Z":
            has_upper = True
        if ch >= "a" and ch <= "z":
            has_lower = True
        if has_num >= 0 and has_num <= 9:
            has_num = True

    if len(password) >= 8 and has_upper and has_lower and has_num:
        return True
    else:
        return False

# %%
def main():

    p = input("Введите пароль: ")
    if checkPassword(p):
        print("Это надежный пароль!")
    else:
        print("Это ненадежный пароль!")

if __name__ == "__main__":
    main()
# Out:
# Введите пароль: 99sSs$$$$*$*$$$$xXxXx
# Это надежный пароль!

# %% [markdown]
# ## Упражнение 3. Автомобиль

# %% [markdown]
# **Условие.** Создайте класс автомобиль и сохраните его в виде программного модуля. Импортируете класс и инициализируйте новый объект. Минимальный набор атрибутов: "марка", "вес", "мощность". Объявите методы: "движение вперед", "поворот направо", "поворот налево", "тормоз", "посигналить".

# %% [markdown]
# https://monica.im/home/chat/Monica/monica?convId=conv%3A03096a90-fd86-4b63-b92b-f8deaef10df0

# %% [markdown]
# **Перепишите код решения и запустите его**
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# Ваш код

# %%writefile car.py

class Car():
    Name_Class = 'Cars'

    # Attributes
    def __init__ (self, mark, wight, power):
        self.mark = mark
        self.wight = wight
        self.power = power

    # Methods
    def move_forward(self):
        print("It's moving forward.")
    def turn_right(self):
        print("It's turning right.")
    def turn_left(self):
        print("It's turning left.")
    def brake(self):
        print("It's braking.")
    def honk(self):
        print("It's honking.")
# Out:
# Writing car.py

# %%
from car import Car

my_car = Car('BMW', '5 ton', '16 horses')
print(my_car.Name_Class)
print(my_car.mark)
print(my_car.wight)
print(my_car.power)
# Out:
# Cars
# BMW
# 5 ton
# 16 horses
